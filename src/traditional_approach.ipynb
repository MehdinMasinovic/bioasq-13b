# %%
# Importing necessary libraries
import requests
import json
import string

import nltk
from nltk.tokenize import word_tokenize

# %%
import ssl

# Diable SSL verification to avoid certificate errors when downloaing nltk resources
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

# Download nltk stopwords and punkt tokenizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /home/jonathan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jonathan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/jonathan/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# ## Loading training data

# %%
from utils import load_bioasq_questions
bioasq_13b_questions = load_bioasq_questions('../data/BioASQ-task13bPhaseB-testset4', num_questions=None, test=True)

# Check the number of questions
print(f"Number of BioASQ 13b questions: {len(bioasq_13b_questions)}")
# Out:
# Number of BioASQ 13b questions: 85

# %% [markdown]
# ## PubMed's API

# %% [markdown]
# ## Traditional IR model

# %% [markdown]
# ### Step 1: Extract keywords from questions

# %% [markdown]
# #### Ideal preprocessing - Apply word2vec

# %%
from utils import load_vectors_gensim

types_file = '../data/word2vecTools/types.txt'
vectors_file = '../data/word2vecTools/vectors.txt'

w2v_model = load_vectors_gensim(types_file, vectors_file, 200)

# %%
from utils import expand_question_with_w2v, build_boolean_query

def expand_question(question):

    question['keywords'] = expand_question_with_w2v(question['body'], w2v_model)

    question['query'] = build_boolean_query(question['keywords'])

    return question

for i, question in enumerate(bioasq_13b_questions):
    # Expand the question using word2vec
    question = expand_question(question)

    # Print the expanded question
    print(f"Expanded Question {i+1}:")
    print(f"Keywords: {question['keywords']}")
    print(f"Query: {question['query']}")
    print()
# Out:
# Expanded Question 1:
# Keywords: {'zotiraciclib': [], 'used': ['utilized', 'employed', 'applied'], 'glioblastoma': ['glioma', 'medulloblastoma', 'gbm']}
# Query: (zotiraciclib) AND (used OR utilized OR employed OR applied) AND (glioblastoma OR glioma OR medulloblastoma OR gbm)
#
# Expanded Question 2:
# Keywords: {'bronchiectasis': ['bronchiectases', 'emphysema', 'bronchiectatic'], 'chronic': ['acute', 'myeloleucosis', 'non-chronic'], 'acute': ['chronic', 'sub-acute', 'subacute'], 'condition': ['conditions', 'situation', 'circumstance']}
# Query: (bronchiectasis OR bronchiectases OR emphysema OR bronchiectatic) AND (chronic OR acute OR myeloleucosis OR non-chronic) AND (acute OR chronic OR sub-acute OR subacute) AND (condition OR conditions OR situation OR circumstance)
#
# Expanded Question 3:
# Keywords: {'biopharmaceuticals': ['biotherapeutics', 'biopharmaceutical', 'commercialization'], 'role': ['roles', 'plays', 'play'], 'treatment': ['flowcharting', 'videoconference-based', 'recovery-focused'], 'depression': ['anxiety', 'somatization', 'inventory-bdi']}
# Query: (biopharmaceuticals OR biotherapeutics OR biopharmaceutical OR commercialization) AND (role OR roles OR plays OR play) AND (treatment OR flowcharting OR videoconference-based OR recovery-focused) AND (depression OR anxiety OR somatization OR inventory-bdi)
#
# Expanded Question 4:
# Keywords: {'microglia': ['microglial', 'microgliamacrophages', 'macrophagesmicroglia'], 'involved': ['implicated', 'participates', 'regulating'], 'synaptic': ['presynaptic', 'synapses', 'glutamatergic'], 'pruning': ['pruned', 'path-finding', 'arborization'], 'development': ['eudicotyledonous', 'gravisensitivity', 'abaxialized']}
# Query: (microglia OR microglial OR microgliamacrophages OR macrophagesmicroglia) AND (involved OR implicated OR participates OR regulating) AND (synaptic OR presynaptic OR synapses OR glutamatergic) AND (pruning OR pruned OR path-finding OR arborization) AND (development OR eudicotyledonous OR gravisensitivity OR abaxialized)
#
# Expanded Question 5:
# Keywords: {'target': ['targets', 'druggable', 'targeting'], 'fezolinetant': []}
# Query: (target OR targets OR druggable OR targeting) AND (fezolinetant)
#
# Expanded Question 6:
# Keywords: {'complication': ['complications', 'sequela', 'life-threatening'], 'pregnancy': ['puerperium', 'pregnancies', 'miscarriage'], 'treated': ['pretreated', 'pre-treated', 'co-treated'], 'diethylstilbestrol': ['diethylstilboestrol', 'diethylstilbesterol', 'ethynylestradiol']}
# Query: (complication OR complications OR sequela OR life-threatening) AND (pregnancy OR puerperium OR pregnancies OR miscarriage) AND (treated OR pretreated OR pre-treated OR co-treated) AND (diethylstilbestrol OR diethylstilboestrol OR diethylstilbesterol OR ethynylestradiol)
#
# Expanded Question 7:
# Keywords: {'biopharmaceuticals': ['biotherapeutics', 'biopharmaceutical', 'commercialization'], 'pediatric': ['paediatric', 'fifteen-bed', 'hematology-oncology'], 'bronchiolitis': ['boop', 'pneumonia', 'croup']}
# Query: (biopharmaceuticals OR biotherapeutics OR biopharmaceutical OR commercialization) AND (pediatric OR paediatric OR fifteen-bed OR hematology-oncology) AND (bronchiolitis OR boop OR pneumonia OR croup)
#
# Expanded Question 8:
# Keywords: {'cycle': ['cycle-related', 'g₂m', 'sg2-m']}
# Query: (cycle OR cycle-related OR g₂m OR sg2-m)
#
# Expanded Question 9:
# Keywords: {'mechanism': ['mechanisms', 'underlying', 'regulation'], 'action': ['actions', 'exerts', 'effect'], 'iptacopan': []}
# Query: (mechanism OR mechanisms OR underlying OR regulation) AND (action OR actions OR exerts OR effect) AND (iptacopan)
#
# Expanded Question 10:
# Keywords: {'previous': ['recent', 'earlier', 'preliminary'], 'acronym': ['eponym', 'jeunes', 'eponymously'], 'metabolic': ['non-metabolic', 'insulin-resistance', 'nonmetabolic'], 'steatotic': ['non-steatotic', 'nonsteatotic', 'livers'], 'liver': ['hepatic', 'kidney', 'livers'], 'diasease': ['nd-lch', 'abscessual', 'radiotomography'], 'masld': []}
# Query: (previous OR recent OR earlier OR preliminary) AND (acronym OR eponym OR jeunes OR eponymously) AND (metabolic OR non-metabolic OR insulin-resistance OR nonmetabolic) AND (steatotic OR non-steatotic OR nonsteatotic OR livers) AND (liver OR hepatic OR kidney OR livers) AND (diasease OR nd-lch OR abscessual OR radiotomography) AND (masld)
#
# Expanded Question 11:
# Keywords: {'genetic': ['phenotypic', 'genetical', 'nongenetic'], 'basis': ['based', 'basing', 'grounds'], 'addiction': ['useabuse', 'addictions', 'addictive']}
# Query: (genetic OR phenotypic OR genetical OR nongenetic) AND (basis OR based OR basing OR grounds) AND (addiction OR useabuse OR addictions OR addictive)
#
# Expanded Question 12:
# Keywords: {'natural': ['killer-like', 'human-made', 'nidality'], 'killer': ['nk', 'killer-like', 'nk-like'], 'nk': ['nk-like', 'killer', 'natural-killer'], 'cells': ['hla-a0202', 'bsab-directed', 'n-ras-gtp'], 'require': ['necessitate', 'preclude', 'permit'], 'antigen': ['antigens', 'em2g11', 'myeloid-histiocyte'], 'presentation': ['presentations', 'picture', 'presenting'], 'eliminate': ['prevent', 'minimize', 'reduce'], 'cancer': ['cancers', 'crc', 'caner']}
# Query: (natural OR killer-like OR human-made OR nidality) AND (killer OR nk OR killer-like OR nk-like) AND (nk OR nk-like OR killer OR natural-killer) AND (cells OR hla-a0202 OR bsab-directed OR n-ras-gtp) AND (require OR necessitate OR preclude OR permit) AND (antigen OR antigens OR em2g11 OR myeloid-histiocyte) AND (presentation OR presentations OR picture OR presenting) AND (eliminate OR prevent OR minimize OR reduce) AND (cancer OR cancers OR crc OR caner)
#
# Expanded Question 13:
# Keywords: {'targets': ['target', 'drugable', 'therapeutics'], 'blinatumomab': ['idec-c2b8', 'dacetuzumab', 'milatuzumab']}
# Query: (targets OR target OR drugable OR therapeutics) AND (blinatumomab OR idec-c2b8 OR dacetuzumab OR milatuzumab)
#
# Expanded Question 14:
# Keywords: {'relationship': ['relationships', 'interrelationship', 'relation'], 'bronchiectasis': ['bronchiectases', 'emphysema', 'bronchiectatic'], 'erdosteine': ['edaravone', 'bicyclol', 'epc-k1']}
# Query: (relationship OR relationships OR interrelationship OR relation) AND (bronchiectasis OR bronchiectases OR emphysema OR bronchiectatic) AND (erdosteine OR edaravone OR bicyclol OR epc-k1)
#
# Expanded Question 15:
# Keywords: {'receptor': ['receptors', 'hmc5', '5-nonyloxytryptamine'], 'agonists': ['agonist', 'antagonists', 'agonism'], 'used': ['utilized', 'employed', 'applied'], 'obesity': ['dyslipidemia', 'overweightobesity', 'adiposity'], 'children': ['adolescents', 'adults', 'toddlers'], '10': ['⋜', '005', '20-09'], 'years': ['33-168', '8-73', '35-96'], 'age': ['ages', 'age33', 'age-group']}
# Query: (receptor OR receptors OR hmc5 OR 5-nonyloxytryptamine) AND (agonists OR agonist OR antagonists OR agonism) AND (used OR utilized OR employed OR applied) AND (obesity OR dyslipidemia OR overweightobesity OR adiposity) AND (children OR adolescents OR adults OR toddlers) AND (10 OR ⋜ OR 005 OR 20-09) AND (years OR 33-168 OR 8-73 OR 35-96) AND (age OR ages OR age33 OR age-group)
#
# Expanded Question 16:
# Keywords: {'radiomic': [], 'features': ['characteristics', 'appearances', 'manifestations'], 'useful': ['valuable', 'helpful', 'suitable'], 'predicting': ['prediction', 'predict', 'predictor'], 'survival': ['tat-puralpha', 'tum-l', 'hnnt-2'], 'glioblastoma': ['glioma', 'medulloblastoma', 'gbm'], 'patients': ['fdg-positive', 'over-staged', 'reexcisions']}
# Query: (radiomic) AND (features OR characteristics OR appearances OR manifestations) AND (useful OR valuable OR helpful OR suitable) AND (predicting OR prediction OR predict OR predictor) AND (survival OR tat-puralpha OR tum-l OR hnnt-2) AND (glioblastoma OR glioma OR medulloblastoma OR gbm) AND (patients OR fdg-positive OR over-staged OR reexcisions)
#
# Expanded Question 17:
# Keywords: {'patients': ['fdg-positive', 'over-staged', 'reexcisions'], 'acute': ['chronic', 'sub-acute', 'subacute'], 'liver': ['hepatic', 'kidney', 'livers'], 'failure': ['congestive', 'failure-related', 'failurechf'], 'associated': ['correlated', 'related', 'correlates'], 'paracetamol': ['acetaminophen', 'metamizole', 'dextropropoxyphene'], 'overdose': ['overdoses', 'overdosage', 'self-poisoning'], 'treatment': ['flowcharting', 'videoconference-based', 'recovery-focused'], 'improve': ['enhance', 'optimise', 'optimize'], 'survival': ['tat-puralpha', 'tum-l', 'hnnt-2']}
# Query: (patients OR fdg-positive OR over-staged OR reexcisions) AND (acute OR chronic OR sub-acute OR subacute) AND (liver OR hepatic OR kidney OR livers) AND (failure OR congestive OR failure-related OR failurechf) AND (associated OR correlated OR related OR correlates) AND (paracetamol OR acetaminophen OR metamizole OR dextropropoxyphene) AND (overdose OR overdoses OR overdosage OR self-poisoning) AND (treatment OR flowcharting OR videoconference-based OR recovery-focused) AND (improve OR enhance OR optimise OR optimize) AND (survival OR tat-puralpha OR tum-l OR hnnt-2)
#
# Expanded Question 18:
# Keywords: {'pharmacological': ['pharmacologic', 'neuropharmacological', 'rhojpak1'], 'treatment': ['flowcharting', 'videoconference-based', 'recovery-focused'], 'urinary': ['excretions', 'alpha1-microg', 'excretion'], 'schistosomiasis': ['filariasis', 'opisthorchiasis', 'clonorchiasis']}
# Query: (pharmacological OR pharmacologic OR neuropharmacological OR rhojpak1) AND (treatment OR flowcharting OR videoconference-based OR recovery-focused) AND (urinary OR excretions OR alpha1-microg OR excretion) AND (schistosomiasis OR filariasis OR opisthorchiasis OR clonorchiasis)
#
# Expanded Question 19:
# Keywords: {'types': ['kinds', 'classes', 'sub-types'], 'features': ['characteristics', 'appearances', 'manifestations'], 'typically': ['usually', 'often', 'generally'], 'extracted': ['extracting', 'prepared', 'cleaned'], 'radiomics': []}
# Query: (types OR kinds OR classes OR sub-types) AND (features OR characteristics OR appearances OR manifestations) AND (typically OR usually OR often OR generally) AND (extracted OR extracting OR prepared OR cleaned) AND (radiomics)
#
# Expanded Question 20:
# Keywords: {'diseases': ['pathologies', 'ailments', 'disease'], 'treated': ['pretreated', 'pre-treated', 'co-treated'], 'fecal': ['faecal', 'feces', 'stool'], 'transplants': ['transplantations', 'transplantation', 'transplant']}
# Query: (diseases OR pathologies OR ailments OR disease) AND (treated OR pretreated OR pre-treated OR co-treated) AND (fecal OR faecal OR feces OR stool) AND (transplants OR transplantations OR transplantation OR transplant)
#
# Expanded Question 21:
# Keywords: {'sertraline': ['paroxetine', 'fluvoxamine', 'citalopram'], 'used': ['utilized', 'employed', 'applied'], 'children': ['adolescents', 'adults', 'toddlers'], '10': ['⋜', '005', '20-09']}
# Query: (sertraline OR paroxetine OR fluvoxamine OR citalopram) AND (used OR utilized OR employed OR applied) AND (children OR adolescents OR adults OR toddlers) AND (10 OR ⋜ OR 005 OR 20-09)
#
# Expanded Question 22:
# Keywords: {'cells': ['hla-a0202', 'bsab-directed', 'n-ras-gtp'], 'primary': ['secondary', 'care-based', 'non-primary']}
# Query: (cells OR hla-a0202 OR bsab-directed OR n-ras-gtp) AND (primary OR secondary OR care-based OR non-primary)
#
# Expanded Question 23:
# Keywords: {'misfolded': ['malfolded', 'aggregation-prone', 'misfolding'], 'aggregated': ['aggregate', 'aggregates', 'non-aggregated'], 'proteins': ['protein', 'polypeptides', 'hsp70s'], 'build': ['create', 'formulate', 'organize'], 'neurodegenerative': ['synucleinopathies', 'neuro-degenerative', 'tauopathies'], 'illnesses': ['illness', 'ailments', 'disorders'], 'causes': ['cause', 'causing', 'leading'], 'neuronal': ['astrocyte', 'neuron', 'astroglial'], 'dysfunction': ['dysfunctions', 'disfunction', 'function'], 'ultimately': ['eventually', 'hopefully', 'eventual'], 'death': ['paraptotic', 'nonsudden', 'necrosis-like']}
# Query: (misfolded OR malfolded OR aggregation-prone OR misfolding) AND (aggregated OR aggregate OR aggregates OR non-aggregated) AND (proteins OR protein OR polypeptides OR hsp70s) AND (build OR create OR formulate OR organize) AND (neurodegenerative OR synucleinopathies OR neuro-degenerative OR tauopathies) AND (illnesses OR illness OR ailments OR disorders) AND (causes OR cause OR causing OR leading) AND (neuronal OR astrocyte OR neuron OR astroglial) AND (dysfunction OR dysfunctions OR disfunction OR function) AND (ultimately OR eventually OR hopefully OR eventual) AND (death OR paraptotic OR nonsudden OR necrosis-like)
#
# Expanded Question 24:
# Keywords: {'differential': ['display-pcr', 'bulge-mismatches', 'hyper-dsc'], 'traits': ['yield-component', 'yield-associated', 'trait'], 'autism': ['autistic', 'asd', 'asds'], 'spectrum': ['spectrums', 'spectra', 'nlpf'], 'disorders': ['disorder', 'psychopathologies', 'non-co-occurring'], 'girls': ['boys', 'adolescents', 'preadolescents']}
# Query: (differential OR display-pcr OR bulge-mismatches OR hyper-dsc) AND (traits OR yield-component OR yield-associated OR trait) AND (autism OR autistic OR asd OR asds) AND (spectrum OR spectrums OR spectra OR nlpf) AND (disorders OR disorder OR psychopathologies OR non-co-occurring) AND (girls OR boys OR adolescents OR preadolescents)
#
# Expanded Question 25:
# Keywords: {'major': ['minor', 'main', 'principal'], 'classes': ['categories', 'types', 'kinds'], 'immunoglobulins': ['immunoglobulin', 'igg', 'immunoglobins']}
# Query: (major OR minor OR main OR principal) AND (classes OR categories OR types OR kinds) AND (immunoglobulins OR immunoglobulin OR igg OR immunoglobins)
#
# Expanded Question 26:
# Keywords: {'please': ['publishers', 'httpwwwjhcorg', 'you'], 'list': ['lists', 'listing', 'to-do'], 'dora': ['doras', 'konda', 'koya'], 'type': ['parenti-fraccaro', 'type-ii', 'i-trimer'], 'drugs': ['agents', 'drug', 'medications']}
# Query: (please OR publishers OR httpwwwjhcorg OR you) AND (list OR lists OR listing OR to-do) AND (dora OR doras OR konda OR koya) AND (type OR parenti-fraccaro OR type-ii OR i-trimer) AND (drugs OR agents OR drug OR medications)
#
# Expanded Question 27:
# Keywords: {'takotsubo': ['tako-tsubo', 'dilative', 'takotsubo-like'], 'cardiomyopathy': ['cardiomyopathies', 'myocardiopathy', 'dcm'], 'common': ['frequent', 'prevalent', 'commonest'], 'men': ['women', 'premenopausal', 'middle-aged']}
# Query: (takotsubo OR tako-tsubo OR dilative OR takotsubo-like) AND (cardiomyopathy OR cardiomyopathies OR myocardiopathy OR dcm) AND (common OR frequent OR prevalent OR commonest) AND (men OR women OR premenopausal OR middle-aged)
#
# Expanded Question 28:
# Keywords: {'radiomics': []}
# Query: (radiomics)
#
# Expanded Question 29:
# Keywords: {'cause': ['causes', 'causing', 'sequela'], 'fibromyalgia': ['fibrositis', 'fms', 'cfs']}
# Query: (cause OR causes OR causing OR sequela) AND (fibromyalgia OR fibrositis OR fms OR cfs)
#
# Expanded Question 30:
# Keywords: {'recommended': ['mandatory', 'recommending', 'advised'], 'prevention': ['preventative', 'preventive', 'programmes'], 'osteoporosis': ['osteopenia', 'osteoporotic', 'osteopenic'], 'postmenopausal': ['post-menopausal', 'premenopausal', 'perimenopausal'], 'women': ['men', 'primigravidas', 'premenopausal']}
# Query: (recommended OR mandatory OR recommending OR advised) AND (prevention OR preventative OR preventive OR programmes) AND (osteoporosis OR osteopenia OR osteoporotic OR osteopenic) AND (postmenopausal OR post-menopausal OR premenopausal OR perimenopausal) AND (women OR men OR primigravidas OR premenopausal)
#
# Expanded Question 31:
# Keywords: {'functions': ['function', 'processes', 'regulators'], 'astrocytes': ['astroglia', 'oligodendrocytes', 'microglia'], 'cns': ['nervous', 'ens', 'extra-central']}
# Query: (functions OR function OR processes OR regulators) AND (astrocytes OR astroglia OR oligodendrocytes OR microglia) AND (cns OR nervous OR ens OR extra-central)
#
# Expanded Question 32:
# Keywords: {'laparoscopic': ['laparoscopic-assisted', 'laparotomic', 'single-port'], 'salpingectomy': ['salpingostomy', 'adnexectomy', 'myomectomy'], 'used': ['utilized', 'employed', 'applied'], 'treat': ['manage', 'palliate', 'diagnose'], 'testicular': ['testis', 'testes', 'testicles'], 'cancer': ['cancers', 'crc', 'caner']}
# Query: (laparoscopic OR laparoscopic-assisted OR laparotomic OR single-port) AND (salpingectomy OR salpingostomy OR adnexectomy OR myomectomy) AND (used OR utilized OR employed OR applied) AND (treat OR manage OR palliate OR diagnose) AND (testicular OR testis OR testes OR testicles) AND (cancer OR cancers OR crc OR caner)
#
# Expanded Question 33:
# Keywords: {'factors': ['modifiable', 'variables', 'non-modifiable'], 'associated': ['correlated', 'related', 'correlates'], 'thyroid': ['thyroidal', 'nonthyroid', 'hyperfunctioning'], 'cancer': ['cancers', 'crc', 'caner']}
# Query: (factors OR modifiable OR variables OR non-modifiable) AND (associated OR correlated OR related OR correlates) AND (thyroid OR thyroidal OR nonthyroid OR hyperfunctioning) AND (cancer OR cancers OR crc OR caner)
#
# Expanded Question 34:
# Keywords: {'glioblastoma': ['glioma', 'medulloblastoma', 'gbm'], 'tumors': ['tumours', 'neoplasms', 'histotypes'], 'high': ['low', 'highest', 'medium-high'], 'degree': ['extent', 'severity', 'moderate'], 'lymphocyte': ['t-lymphocyte', 't-cell', 't-lymphocytes'], 'infiltration': ['infiltrate', 'infiltrations', 'infiltrates']}
# Query: (glioblastoma OR glioma OR medulloblastoma OR gbm) AND (tumors OR tumours OR neoplasms OR histotypes) AND (high OR low OR highest OR medium-high) AND (degree OR extent OR severity OR moderate) AND (lymphocyte OR t-lymphocyte OR t-cell OR t-lymphocytes) AND (infiltration OR infiltrate OR infiltrations OR infiltrates)
#
# Expanded Question 35:
# Keywords: {'please': ['publishers', 'httpwwwjhcorg', 'you'], 'list': ['lists', 'listing', 'to-do'], 'types': ['kinds', 'classes', 'sub-types'], 'videolaryngoscopy': ['stroboscopy', 'videostroboscopy', 'nasopharyngoscopy'], 'adults': ['adolescents', 'children', 'people'], 'undergoing': ['underwent', 'elective', 'scheduled'], 'tracheal': ['trachea', 'airway', 'endotracheal'], 'intubation': ['intubations', 'suctioning', 'extubation']}
# Query: (please OR publishers OR httpwwwjhcorg OR you) AND (list OR lists OR listing OR to-do) AND (types OR kinds OR classes OR sub-types) AND (videolaryngoscopy OR stroboscopy OR videostroboscopy OR nasopharyngoscopy) AND (adults OR adolescents OR children OR people) AND (undergoing OR underwent OR elective OR scheduled) AND (tracheal OR trachea OR airway OR endotracheal) AND (intubation OR intubations OR suctioning OR extubation)
#
# Expanded Question 36:
# Keywords: {'electroconvulsive': ['electro-convulsive', 'ect', 'left-unilateral'], 'therapy': ['treatment', 'therapies', 'regimens'], 'used': ['utilized', 'employed', 'applied'], 'type': ['parenti-fraccaro', 'type-ii', 'i-trimer'], 'epilepsy': ['epilepsies', 'pharmacoresistant', 'tle']}
# Query: (electroconvulsive OR electro-convulsive OR ect OR left-unilateral) AND (therapy OR treatment OR therapies OR regimens) AND (used OR utilized OR employed OR applied) AND (type OR parenti-fraccaro OR type-ii OR i-trimer) AND (epilepsy OR epilepsies OR pharmacoresistant OR tle)
#
# Expanded Question 37:
# Keywords: {'characteristics': ['features', 'attributes', 'variables'], 'macrophage': ['monocyte', 'monocytemacrophage', 'macrophages'], 'polarization': ['polarisation', 'polarizations', 'time-resolved'], 'paradigm': ['paradigms', 'task', 'operant-based'], 'tumor': ['tumour', 'tumoral', 'tumors'], 'microenvironment': ['micro-environment', 'microenvironments', 'microenvironmental']}
# Query: (characteristics OR features OR attributes OR variables) AND (macrophage OR monocyte OR monocytemacrophage OR macrophages) AND (polarization OR polarisation OR polarizations OR time-resolved) AND (paradigm OR paradigms OR task OR operant-based) AND (tumor OR tumour OR tumoral OR tumors) AND (microenvironment OR micro-environment OR microenvironments OR microenvironmental)
#
# Expanded Question 38:
# Keywords: {'nissen': ['nissen-rossetti', 'toupet', 'fundoplication'], 'fundoplication': ['fundoplications', 'toupet', 'cardiomyotomy']}
# Query: (nissen OR nissen-rossetti OR toupet OR fundoplication) AND (fundoplication OR fundoplications OR toupet OR cardiomyotomy)
#
# Expanded Question 39:
# Keywords: {'genetic': ['phenotypic', 'genetical', 'nongenetic'], 'variants': ['variant', 'alleles', 'c137ga'], 'turner': ['turners', 'klinefelter', 'klinefelters'], 'syndrome': ['syndrome-like', 'syndrom', 'syndromes']}
# Query: (genetic OR phenotypic OR genetical OR nongenetic) AND (variants OR variant OR alleles OR c137ga) AND (turner OR turners OR klinefelter OR klinefelters) AND (syndrome OR syndrome-like OR syndrom OR syndromes)
#
# Expanded Question 40:
# Keywords: {'organelle': ['organelles', 'mitochondrion', 'organellar'], 'responsible': ['involved', 'prerequisite', 'accounted'], 'atp': ['adp', 'atpgammas', 'adenosine-5-triphosphate'], 'production': ['productions', 'over-production', 'generation']}
# Query: (organelle OR organelles OR mitochondrion OR organellar) AND (responsible OR involved OR prerequisite OR accounted) AND (atp OR adp OR atpgammas OR adenosine-5-triphosphate) AND (production OR productions OR over-production OR generation)
#
# Expanded Question 41:
# Keywords: {'age': ['ages', 'age33', 'age-group'], 'group': ['groupthe', 'group1', 'delayed-treatment'], 'commonly': ['frequently', 'widely', 'often'], 'affected': ['influenced', 'unaffected', 'altered'], 'biliary': ['extrahepatic', 'bile', 'hepatolithiasis'], 'atresia': ['eatef', 'atresias', 'fistulaesophageal']}
# Query: (age OR ages OR age33 OR age-group) AND (group OR groupthe OR group1 OR delayed-treatment) AND (commonly OR frequently OR widely OR often) AND (affected OR influenced OR unaffected OR altered) AND (biliary OR extrahepatic OR bile OR hepatolithiasis) AND (atresia OR eatef OR atresias OR fistulaesophageal)
#
# Expanded Question 42:
# Keywords: {'manifestations': ['manifestation', 'signs', 'protean'], 'gluten': ['gliadin', 'cornstarch', 'gluten-containing']}
# Query: (manifestations OR manifestation OR signs OR protean) AND (gluten OR gliadin OR cornstarch OR gluten-containing)
#
# Expanded Question 43:
# Keywords: {'cells': ['hla-a0202', 'bsab-directed', 'n-ras-gtp'], 'enter': ['traverse', 'entering', 're-enter'], 'cns': ['nervous', 'ens', 'extra-central'], 'healthy': ['age-matched', 'aged-matched', 'non-cocaine-dependent'], 'individuals': ['persons', 'people', 'subjects']}
# Query: (cells OR hla-a0202 OR bsab-directed OR n-ras-gtp) AND (enter OR traverse OR entering OR re-enter) AND (cns OR nervous OR ens OR extra-central) AND (healthy OR age-matched OR aged-matched OR non-cocaine-dependent) AND (individuals OR persons OR people OR subjects)
#
# Expanded Question 44:
# Keywords: {'urolithiasis': ['nephrolithiasis', 'lithiasis', 'calculi'], 'thing': ['something', 'everything', 'knows'], 'kidney': ['kidneys', 'liver', 'renal'], 'stones': ['calculi', 'stone', 'concrements']}
# Query: (urolithiasis OR nephrolithiasis OR lithiasis OR calculi) AND (thing OR something OR everything OR knows) AND (kidney OR kidneys OR liver OR renal) AND (stones OR calculi OR stone OR concrements)
#
# Expanded Question 45:
# Keywords: {'acquire': ['retain', 'manipulate', 'adapt'], 'legionella': ['pneumophila', 'non-pneumophila', 'legionellae'], 'pneumophila': ['micdadei', 'longbeachae', 'bozemanii']}
# Query: (acquire OR retain OR manipulate OR adapt) AND (legionella OR pneumophila OR non-pneumophila OR legionellae) AND (pneumophila OR micdadei OR longbeachae OR bozemanii)
#
# Expanded Question 46:
# Keywords: {'role': ['roles', 'plays', 'play'], 'choroid': ['choroids', 'chorioid', 'choroideus'], 'plexus': ['plexuses', 'plexi', 'basiepithelial'], 'immune': ['humoral', 'immunity', 'innate'], 'surveillance': ['essti', 'countrywide', 'state-based']}
# Query: (role OR roles OR plays OR play) AND (choroid OR choroids OR chorioid OR choroideus) AND (plexus OR plexuses OR plexi OR basiepithelial) AND (immune OR humoral OR immunity OR innate) AND (surveillance OR essti OR countrywide OR state-based)
#
# Expanded Question 47:
# Keywords: {'antibiotic': ['antibiotics', 'antimicrobials', 'fluoroquinolone'], 'use': ['usage', 'users', 'misuse'], 'induced': ['induces', 'triggered', 'provoked'], 'hiccups': ['hiccup', 'singultus', 'vomiting']}
# Query: (antibiotic OR antibiotics OR antimicrobials OR fluoroquinolone) AND (use OR usage OR users OR misuse) AND (induced OR induces OR triggered OR provoked) AND (hiccups OR hiccup OR singultus OR vomiting)
#
# Expanded Question 48:
# Keywords: {'snake': ['bothrops', 'elapid', 'venom'], 'antivenoms': ['antivenom', 'bothropic', 'venoms'], 'contain': ['contained', 'consist', 'possess']}
# Query: (snake OR bothrops OR elapid OR venom) AND (antivenoms OR antivenom OR bothropic OR venoms) AND (contain OR contained OR consist OR possess)
#
# Expanded Question 49:
# Keywords: {'microglia': ['microglial', 'microgliamacrophages', 'macrophagesmicroglia'], 'derived': ['deriving', 'derives', 'generated'], 'lineage': ['lineages', 'linage', 'progenitors'], 'peripheral': ['peripheric', 'mononuclear', 'pbmcs'], 'macrophages': ['mphi', 'mphis', 'monocytesmacrophages']}
# Query: (microglia OR microglial OR microgliamacrophages OR macrophagesmicroglia) AND (derived OR deriving OR derives OR generated) AND (lineage OR lineages OR linage OR progenitors) AND (peripheral OR peripheric OR mononuclear OR pbmcs) AND (macrophages OR mphi OR mphis OR monocytesmacrophages)
#
# Expanded Question 50:
# Keywords: {'gastric': ['duodenal', 'colonic', 'oesophageal'], 'pacemaker': ['pacemakers', 'multiprogrammable', 'ddd-type'], 'work': ['paper', 'article', 'study']}
# Query: (gastric OR duodenal OR colonic OR oesophageal) AND (pacemaker OR pacemakers OR multiprogrammable OR ddd-type) AND (work OR paper OR article OR study)
#
# Expanded Question 51:
# Keywords: {'newborns': ['neonates', 'babies', 'infants'], 'glaucoma': ['poag', 'glaucomas', 'open-angle']}
# Query: (newborns OR neonates OR babies OR infants) AND (glaucoma OR poag OR glaucomas OR open-angle)
#
# Expanded Question 52:
# Keywords: {'recent': ['previous', 'anecdotal', 'past'], 'advances': ['advancements', 'developments', 'breakthroughs'], 'cancer': ['cancers', 'crc', 'caner'], 'immunotherapy': ['immunotherapies', 'immunotherapeutic', 'dc-based']}
# Query: (recent OR previous OR anecdotal OR past) AND (advances OR advancements OR developments OR breakthroughs) AND (cancer OR cancers OR crc OR caner) AND (immunotherapy OR immunotherapies OR immunotherapeutic OR dc-based)
#
# Expanded Question 53:
# Keywords: {'delirium': ['delirious', 'tremens', 'pre-delirium'], 'frequent': ['common', 'frequently', 'prevalent'], 'complication': ['complications', 'sequela', 'life-threatening'], 'cardiac': ['noncardiac', 'anesthesia-attributable', 'heart'], 'surgery': ['surgeries', 'operation', 'operations']}
# Query: (delirium OR delirious OR tremens OR pre-delirium) AND (frequent OR common OR frequently OR prevalent) AND (complication OR complications OR sequela OR life-threatening) AND (cardiac OR noncardiac OR anesthesia-attributable OR heart) AND (surgery OR surgeries OR operation OR operations)
#
# Expanded Question 54:
# Keywords: {'phobias': ['phobia', 'phobic', 'panicagoraphobia'], 'affecting': ['altering', 'influencing', 'impacting'], 'humans': ['rodents', 'non-human', 'primates']}
# Query: (phobias OR phobia OR phobic OR panicagoraphobia) AND (affecting OR altering OR influencing OR impacting) AND (humans OR rodents OR non-human OR primates)
#
# Expanded Question 55:
# Keywords: {'convolutional': ['wnn', 'watts-strogatz', 'complex-valued'], 'neural': ['platetube', 'tube-derived', 'crest-related'], 'networks': ['network', 'one-hidden-layer', 'sub-networks'], 'cnns': ['hopfield-type', 'slfns', 'multihop'], 'utilized': ['used', 'employed', 'utilised'], 'radiomics': []}
# Query: (convolutional OR wnn OR watts-strogatz OR complex-valued) AND (neural OR platetube OR tube-derived OR crest-related) AND (networks OR network OR one-hidden-layer OR sub-networks) AND (cnns OR hopfield-type OR slfns OR multihop) AND (utilized OR used OR employed OR utilised) AND (radiomics)
#
# Expanded Question 56:
# Keywords: {'please': ['publishers', 'httpwwwjhcorg', 'you'], 'summarize': ['summarise', 'discuss', 'document'], 'graves': ['gravess', 'hashimotos', 'addisons'], 'disease': ['proctor-dix', 'balneoreactions', 'vkorc-1']}
# Query: (please OR publishers OR httpwwwjhcorg OR you) AND (summarize OR summarise OR discuss OR document) AND (graves OR gravess OR hashimotos OR addisons) AND (disease OR proctor-dix OR balneoreactions OR vkorc-1)
#
# Expanded Question 57:
# Keywords: {'studies': ['investigations', 'researches', 'experiments'], 'genetics': ['biology', 'immunology', 'forensics'], 'suicide': ['homicide', 'suicidal', 'ideators']}
# Query: (studies OR investigations OR researches OR experiments) AND (genetics OR biology OR immunology OR forensics) AND (suicide OR homicide OR suicidal OR ideators)
#
# Expanded Question 58:
# Keywords: {'common': ['frequent', 'prevalent', 'commonest'], 'modifications': ['modification', 'ptms', 'alterations'], 'proteins': ['protein', 'polypeptides', 'hsp70s']}
# Query: (common OR frequent OR prevalent OR commonest) AND (modifications OR modification OR ptms OR alterations) AND (proteins OR protein OR polypeptides OR hsp70s)
#
# Expanded Question 59:
# Keywords: {'mioxsys': [], 'oxisperm': [], 'measure': ['measures', 'out-come', 'radiologicalendoscopic'], 'ros': ['rosrns', 'mtros', 'species-induced'], 'reactive': ['speciesros', 'ros', 'rosrns'], 'oxygen': ['o2', 'deliveryoxygen', 'speciesros'], 'species': ['taxa', 'genera', 'morphospecies'], 'sperm': ['spermatozoa', 'sperms', 'spermatozoal']}
# Query: (mioxsys) AND (oxisperm) AND (measure OR measures OR out-come OR radiologicalendoscopic) AND (ros OR rosrns OR mtros OR species-induced) AND (reactive OR speciesros OR ros OR rosrns) AND (oxygen OR o2 OR deliveryoxygen OR speciesros) AND (species OR taxa OR genera OR morphospecies) AND (sperm OR spermatozoa OR sperms OR spermatozoal)
#
# Expanded Question 60:
# Keywords: {'parasitic': ['helminth', 'helminths', 'nematodes'], 'infections': ['infection', 'superinfections', 'nosocomial'], 'cause': ['causes', 'causing', 'sequela'], 'anemia': ['anaemia', 'anemias', 'normocytic-normochromic']}
# Query: (parasitic OR helminth OR helminths OR nematodes) AND (infections OR infection OR superinfections OR nosocomial) AND (cause OR causes OR causing OR sequela) AND (anemia OR anaemia OR anemias OR normocytic-normochromic)
#
# Expanded Question 61:
# Keywords: {'neurotransmitter': ['transmitter', 'neurotransmitters', 'neurotransmission'], 'associated': ['correlated', 'related', 'correlates'], 'muscle': ['muscles', 'cellmyofibroblast-like', 'gastrocnemius'], 'activation': ['ikknf-κb', 'traf-mediated', 'pi-3k-akt']}
# Query: (neurotransmitter OR transmitter OR neurotransmitters OR neurotransmission) AND (associated OR correlated OR related OR correlates) AND (muscle OR muscles OR cellmyofibroblast-like OR gastrocnemius) AND (activation OR ikknf-κb OR traf-mediated OR pi-3k-akt)
#
# Expanded Question 62:
# Keywords: {'medical': ['pharmacy', 'specialty', 'radiology'], 'proceedure': ['diphosphorylethanolamine', '2-bromoacetamide', '13-keto'], 'causes': ['cause', 'causing', 'leading'], 'nephrogenic': ['insipidus', 'perilobar', 'cndi'], 'systemic': ['erythematosous', 'erithematosus', 'erythmatosus'], 'fibrosis': ['symmers', 'fibrosis-like', 'fibrotic']}
# Query: (medical OR pharmacy OR specialty OR radiology) AND (proceedure OR diphosphorylethanolamine OR 2-bromoacetamide OR 13-keto) AND (causes OR cause OR causing OR leading) AND (nephrogenic OR insipidus OR perilobar OR cndi) AND (systemic OR erythematosous OR erithematosus OR erythmatosus) AND (fibrosis OR symmers OR fibrosis-like OR fibrotic)
#
# Expanded Question 63:
# Keywords: {'obesity': ['dyslipidemia', 'overweightobesity', 'adiposity'], 'risk': ['risks', 'nonmodifiable', 'cvrfs'], 'factor': ['factor-', 'tgf-alphaepidermal', 'factor-2'], 'sleep': ['rem', 'wakefulness', 'awakenings'], 'apnea': ['apnoea', 'osa', 'apnoeas']}
# Query: (obesity OR dyslipidemia OR overweightobesity OR adiposity) AND (risk OR risks OR nonmodifiable OR cvrfs) AND (factor OR factor- OR tgf-alphaepidermal OR factor-2) AND (sleep OR rem OR wakefulness OR awakenings) AND (apnea OR apnoea OR osa OR apnoeas)
#
# Expanded Question 64:
# Keywords: {'cancer': ['cancers', 'crc', 'caner'], 'hallmarks': ['hallmark', 'tauopathies', 'reminiscent'], 'characteristically': ['variably', 'occasionally', 'resembling'], 'promoted': ['promotes', 'inhibited', 'suppressed'], 'tumor': ['tumour', 'tumoral', 'tumors'], 'microenvironment': ['micro-environment', 'microenvironments', 'microenvironmental'], 'components': ['component', 'constituents', 'subcomponents'], 'pericytes': ['endothelia', 'sa-asc', 'periendothelial']}
# Query: (cancer OR cancers OR crc OR caner) AND (hallmarks OR hallmark OR tauopathies OR reminiscent) AND (characteristically OR variably OR occasionally OR resembling) AND (promoted OR promotes OR inhibited OR suppressed) AND (tumor OR tumour OR tumoral OR tumors) AND (microenvironment OR micro-environment OR microenvironments OR microenvironmental) AND (components OR component OR constituents OR subcomponents) AND (pericytes OR endothelia OR sa-asc OR periendothelial)
#
# Expanded Question 65:
# Keywords: {'xist': ['tsix', 'xite', 'kcnq1ot1'], 'proteins': ['protein', 'polypeptides', 'hsp70s'], 'mediate': ['modulate', 'mediates', 'regulate'], 'cellular': ['ad5-vector-induced', 'chitin-mediated', 'organismal'], 'process': ['processes', 'process--the', 'multistep']}
# Query: (xist OR tsix OR xite OR kcnq1ot1) AND (proteins OR protein OR polypeptides OR hsp70s) AND (mediate OR modulate OR mediates OR regulate) AND (cellular OR ad5-vector-induced OR chitin-mediated OR organismal) AND (process OR processes OR process--the OR multistep)
#
# Expanded Question 66:
# Keywords: {'typical': ['distinctive', 'peculiar', 'resembling'], 'age': ['ages', 'age33', 'age-group'], 'range': ['ranges', '2-55', '2-80'], 'onset': ['on-set', 'prodromal', 'duration'], 'systemic': ['erythematosous', 'erithematosus', 'erythmatosus'], 'scleroderma': ['ssc', 'sclerodermia', 'polymyositisdermatomyositis']}
# Query: (typical OR distinctive OR peculiar OR resembling) AND (age OR ages OR age33 OR age-group) AND (range OR ranges OR 2-55 OR 2-80) AND (onset OR on-set OR prodromal OR duration) AND (systemic OR erythematosous OR erithematosus OR erythmatosus) AND (scleroderma OR ssc OR sclerodermia OR polymyositisdermatomyositis)
#
# Expanded Question 67:
# Keywords: {'glial': ['astroglial', 'gfap', 'gfap-positive'], 'cells': ['hla-a0202', 'bsab-directed', 'n-ras-gtp'], 'responsible': ['involved', 'prerequisite', 'accounted'], 'myelination': ['myelinogenesis', 'remyelination', 'synaptogenesis'], 'cns': ['nervous', 'ens', 'extra-central']}
# Query: (glial OR astroglial OR gfap OR gfap-positive) AND (cells OR hla-a0202 OR bsab-directed OR n-ras-gtp) AND (responsible OR involved OR prerequisite OR accounted) AND (myelination OR myelinogenesis OR remyelination OR synaptogenesis) AND (cns OR nervous OR ens OR extra-central)
#
# Expanded Question 68:
# Keywords: {'bionda': ['frisa', 'plagiocirrus', 'menorquina']}
# Query: (bionda OR frisa OR plagiocirrus OR menorquina)
#
# Expanded Question 69:
# Keywords: {'indications': ['contraindications', 'indication', 'contra-indications'], 'therapy': ['treatment', 'therapies', 'regimens']}
# Query: (indications OR contraindications OR indication OR contra-indications) AND (therapy OR treatment OR therapies OR regimens)
#
# Expanded Question 70:
# Keywords: {'common': ['frequent', 'prevalent', 'commonest'], 'gain': ['gains', 'weight', 'gainers'], 'glioblastoma': ['glioma', 'medulloblastoma', 'gbm']}
# Query: (common OR frequent OR prevalent OR commonest) AND (gain OR gains OR weight OR gainers) AND (glioblastoma OR glioma OR medulloblastoma OR gbm)
#
# Expanded Question 71:
# Keywords: {'gene': ['genes', 'pseudogene', 'gene-encoding'], 'target': ['targets', 'druggable', 'targeting'], 'zanidatamab': []}
# Query: (gene OR genes OR pseudogene OR gene-encoding) AND (target OR targets OR druggable OR targeting) AND (zanidatamab)
#
# Expanded Question 72:
# Keywords: {'diagnose': ['treat', 'diagnosing', 'diagnosis'], 'hiv': ['rekt', 'dic-positive', 'sbs-ifald'], 'infection': ['infections', 'co-infection', 'coinfection']}
# Query: (diagnose OR treat OR diagnosing OR diagnosis) AND (hiv OR rekt OR dic-positive OR sbs-ifald) AND (infection OR infections OR co-infection OR coinfection)
#
# Expanded Question 73:
# Keywords: {'polymorphism': ['polymorphisms', 'pcr-rflp', 'c-106t'], 'snp': ['snps', 'htsnp', 'tsnp'], 'mutation': ['mutations', 'missense', 'missence']}
# Query: (polymorphism OR polymorphisms OR pcr-rflp OR c-106t) AND (snp OR snps OR htsnp OR tsnp) AND (mutation OR mutations OR missense OR missence)
#
# Expanded Question 74:
# Keywords: {'melatonin': ['mlt', 'n-acetyl-5-methoxytryptamine', 'n-acetylserotonin'], 'found': ['observed', 'noted', 'noticed'], 'human': ['murine', 'mouse', 'immortalized'], 'milk': ['milks', 'colostrum', 'replacers']}
# Query: (melatonin OR mlt OR n-acetyl-5-methoxytryptamine OR n-acetylserotonin) AND (found OR observed OR noted OR noticed) AND (human OR murine OR mouse OR immortalized) AND (milk OR milks OR colostrum OR replacers)
#
# Expanded Question 75:
# Keywords: {'physiopathology': ['etiopathogenesis', 'pathophysiology', 'aetiopathogenesis'], 'alopecia': ['universalis', 'areata', 'rash']}
# Query: (physiopathology OR etiopathogenesis OR pathophysiology OR aetiopathogenesis) AND (alopecia OR universalis OR areata OR rash)
#
# Expanded Question 76:
# Keywords: {'phenotype': ['phenotypes', 'rough-eye', 'phenotypically'], 'switching': ['switch', 'switches', 'switched'], 'melanoma': ['melanomas', 'amelanotic', 'uveal']}
# Query: (phenotype OR phenotypes OR rough-eye OR phenotypically) AND (switching OR switch OR switches OR switched) AND (melanoma OR melanomas OR amelanotic OR uveal)
#
# Expanded Question 77:
# Keywords: {'neoantigen': ['neoantigens', 'antimannan', 'anti-antigen']}
# Query: (neoantigen OR neoantigens OR antimannan OR anti-antigen)
#
# Expanded Question 78:
# Keywords: {'hyaluronic': ['hyaluronan', 'nonanimal-stabilized', 'alginic'], 'acid': ['acid-', 'acids', '2-methylhexanoic'], 'injections': ['injection', 'infusions', 'sc'], 'improve': ['enhance', 'optimise', 'optimize'], 'knee': ['ankle', 'elbow', 'hip'], 'pain': ['legbuttock', 'discomfort', 'pains']}
# Query: (hyaluronic OR hyaluronan OR nonanimal-stabilized OR alginic) AND (acid OR acid- OR acids OR 2-methylhexanoic) AND (injections OR injection OR infusions OR sc) AND (improve OR enhance OR optimise OR optimize) AND (knee OR ankle OR elbow OR hip) AND (pain OR legbuttock OR discomfort OR pains)
#
# Expanded Question 79:
# Keywords: {'transcription': ['transacting', 'transcriptional', 'promoter-specific'], 'factors': ['modifiable', 'variables', 'non-modifiable'], 'important': ['crucial', 'critical', 'indispensable'], 'define': ['delineate', 'establish', 'clarify'], 'human': ['murine', 'mouse', 'immortalized'], 'astrocyte': ['astroglial', 'astrocytes', 'astroglia'], 'identity': ['identities', 'similarity', 'homology']}
# Query: (transcription OR transacting OR transcriptional OR promoter-specific) AND (factors OR modifiable OR variables OR non-modifiable) AND (important OR crucial OR critical OR indispensable) AND (define OR delineate OR establish OR clarify) AND (human OR murine OR mouse OR immortalized) AND (astrocyte OR astroglial OR astrocytes OR astroglia) AND (identity OR identities OR similarity OR homology)
#
# Expanded Question 80:
# Keywords: {'peto': ['petos', 'mantel-haenszel', 'wald'], 'paradox': ['contradiction', 'phenomenon', 'conundrum'], 'associated': ['correlated', 'related', 'correlates'], 'cancer': ['cancers', 'crc', 'caner'], 'rates': ['rate', 'cause-specific', 'cumulative']}
# Query: (peto OR petos OR mantel-haenszel OR wald) AND (paradox OR contradiction OR phenomenon OR conundrum) AND (associated OR correlated OR related OR correlates) AND (cancer OR cancers OR crc OR caner) AND (rates OR rate OR cause-specific OR cumulative)
#
# Expanded Question 81:
# Keywords: {'clostridioides': [], 'difficile': ['perfringens', 'difficile-associated', 'sordellii'], 'aerobe': ['anaerobe', 'capnophilic', 'aerotolerant'], 'anaerobe': ['aerobe', 'asaccharolytic', 'capnophilic'], 'bacterium': ['spore-forming', 'actinobacterium', 'pink-pigmented']}
# Query: (clostridioides) AND (difficile OR perfringens OR difficile-associated OR sordellii) AND (aerobe OR anaerobe OR capnophilic OR aerotolerant) AND (anaerobe OR aerobe OR asaccharolytic OR capnophilic) AND (bacterium OR spore-forming OR actinobacterium OR pink-pigmented)
#
# Expanded Question 82:
# Keywords: {'please': ['publishers', 'httpwwwjhcorg', 'you'], 'list': ['lists', 'listing', 'to-do'], 'benefits': ['benefit', 'downsides', 'outweigh'], 'cotransporter': ['co-transporter', 'cotransporters', 'cotransport'], '2': ['sextiles', 'vpwr', 'ø15'], 'inhibitors': ['inhibitor', 'small-molecule', 'atp-competing']}
# Query: (please OR publishers OR httpwwwjhcorg OR you) AND (list OR lists OR listing OR to-do) AND (benefits OR benefit OR downsides OR outweigh) AND (cotransporter OR co-transporter OR cotransporters OR cotransport) AND (2 OR sextiles OR vpwr OR ø15) AND (inhibitors OR inhibitor OR small-molecule OR atp-competing)
#
# Expanded Question 83:
# Keywords: {'bacteria': ['microorganisms', 'micro-organisms', 'microbes'], 'commonly': ['frequently', 'widely', 'often'], 'causes': ['cause', 'causing', 'leading'], 'urinary': ['excretions', 'alpha1-microg', 'excretion'], 'tract': ['giti', 'urinary-tract', 'tracts'], 'infection': ['infections', 'co-infection', 'coinfection']}
# Query: (bacteria OR microorganisms OR micro-organisms OR microbes) AND (commonly OR frequently OR widely OR often) AND (causes OR cause OR causing OR leading) AND (urinary OR excretions OR alpha1-microg OR excretion) AND (tract OR giti OR urinary-tract OR tracts) AND (infection OR infections OR co-infection OR coinfection)
#
# Expanded Question 84:
# Keywords: {'bacillus': ['pumilus', 'megaterium', 'atcc6633'], 'clausii': ['weihenstephanensis', 'pumilus', 'laterosporus'], 'probiotic': ['probiotics', 'synbiotic', 'lactobacillus']}
# Query: (bacillus OR pumilus OR megaterium OR atcc6633) AND (clausii OR weihenstephanensis OR pumilus OR laterosporus) AND (probiotic OR probiotics OR synbiotic OR lactobacillus)
#
# Expanded Question 85:
# Keywords: {'symptoms': ['symptomatology', 'symptom', 'complaints'], 'chlamydia': ['trachomatis', 'chlamydial', 'chlamydophila'], 'genital': ['urogenital', 'anogenital', 'extragenital'], 'infection': ['infections', 'co-infection', 'coinfection'], 'women': ['men', 'primigravidas', 'premenopausal']}
# Query: (symptoms OR symptomatology OR symptom OR complaints) AND (chlamydia OR trachomatis OR chlamydial OR chlamydophila) AND (genital OR urogenital OR anogenital OR extragenital) AND (infection OR infections OR co-infection OR coinfection) AND (women OR men OR primigravidas OR premenopausal)

# %% [markdown]
# ### Step 2: Consume PubMed's API to get relevant documents

# %%
# Get the most relevant documents for each question according to the PubMed API
# and save them in a new attribute documents_api
from utils import get_most_relevant_documents

for question in bioasq_13b_questions:
    documents = get_most_relevant_documents(question['query'], page=0, documents_per_page=50)
    question['documents_api'] = documents
    question['documents'] = []

    print(f"Documents found for question `{question['id']}`: {len(documents)}")
# Out:
# Documents found for question `67e6cf2618b1e36f2e0000d0`: 0
# Documents found for question `680d5e47353a4a2e6b000005`: 50
# Documents found for question `680f4a68353a4a2e6b000007`: 50
# Documents found for question `680a083218b1e36f2e00014d`: 50
# Documents found for question `67e5557c18b1e36f2e0000ac`: 16
# Documents found for question `6810fef8353a4a2e6b000016`: 50
# Documents found for question `6810cb23353a4a2e6b000012`: 50
# Documents found for question `680bc7a718b1e36f2e000156`: 50
# Documents found for question `67e56f2018b1e36f2e0000b0`: 8
# Documents found for question `67fe5f0918b1e36f2e000144`: 0
# Documents found for question `67fbe4d718b1e36f2e00011d`: 49
# Documents found for question `680a079718b1e36f2e000147`: 50
# Documents found for question `67e5749b18b1e36f2e0000b5`: 50
# Documents found for question `680d5f2a353a4a2e6b000006`: 1
# Documents found for question `6810f6f0353a4a2e6b000015`: 0
# Documents found for question `680a237618b1e36f2e000152`: 32
# Documents found for question `68110110353a4a2e6b000018`: 21
# Documents found for question `680f4c63353a4a2e6b00000d`: 50
# Documents found for question `680a087218b1e36f2e00014f`: 50
# Documents found for question `6810daad353a4a2e6b000013`: 50
# Documents found for question `6810c27b353a4a2e6b000010`: 0
# Documents found for question `680a07a418b1e36f2e000148`: 50
# Documents found for question `67fbd58c18b1e36f2e00010e`: 3
# Documents found for question `67fbe10618b1e36f2e000111`: 50
# Documents found for question `680fcb72353a4a2e6b00000e`: 49
# Documents found for question `6805568118b1e36f2e000145`: 0
# Documents found for question `67e26b0b18b1e36f2e000073`: 49
# Documents found for question `680a080b18b1e36f2e00014b`: 50
# Documents found for question `6810db0a353a4a2e6b000014`: 50
# Documents found for question `67e2cfcf18b1e36f2e00009a`: 50
# Documents found for question `680a081d18b1e36f2e00014c`: 50
# Documents found for question `6810ff8f353a4a2e6b000017`: 0
# Documents found for question `67fbe21818b1e36f2e000113`: 50
# Documents found for question `67fc20ee18b1e36f2e00012a`: 50
# Documents found for question `67f8527318b1e36f2e000104`: 0
# Documents found for question `680f4ae9353a4a2e6b000009`: 5
# Documents found for question `67fd922518b1e36f2e000143`: 6
# Documents found for question `67fc1a3818b1e36f2e000129`: 50
# Documents found for question `67e285b018b1e36f2e00007b`: 50
# Documents found for question `680a07f918b1e36f2e00014a`: 50
# Documents found for question `67cdc78381b102733300001a`: 50
# Documents found for question `67d7ff2c18b1e36f2e000049`: 50
# Documents found for question `680a084018b1e36f2e00014e`: 50
# Documents found for question `67cde41a81b102733300001d`: 49
# Documents found for question `67e2b80618b1e36f2e00008f`: 50
# Documents found for question `680a21ff18b1e36f2e000151`: 39
# Documents found for question `67fc546c18b1e36f2e000130`: 49
# Documents found for question `680f4aa6353a4a2e6b000008`: 50
# Documents found for question `680a078618b1e36f2e000146`: 50
# Documents found for question `67e098cb18b1e36f2e00006d`: 48
# Documents found for question `67d6be8a18b1e36f2e000022`: 49
# Documents found for question `680bc74618b1e36f2e000155`: 50
# Documents found for question `67f857eb18b1e36f2e000105`: 50
# Documents found for question `67e291a718b1e36f2e000081`: 50
# Documents found for question `680b7f4818b1e36f2e000154`: 33
# Documents found for question `67cde43c81b102733300001e`: 48
# Documents found for question `67e2958018b1e36f2e000084`: 50
# Documents found for question `680c174d353a4a2e6b000001`: 49
# Documents found for question `67e0053118b1e36f2e000067`: 1
# Documents found for question `67e2a8d618b1e36f2e000088`: 50
# Documents found for question `680a07ed18b1e36f2e000149`: 50
# Documents found for question `67e93f2d18b1e36f2e0000db`: 0
# Documents found for question `67e2bde318b1e36f2e000093`: 50
# Documents found for question `680c137818b1e36f2e000158`: 0
# Documents found for question `67ca061181b102733300000a`: 50
# Documents found for question `67e26d6218b1e36f2e000074`: 17
# Documents found for question `680a21eb18b1e36f2e000150`: 50
# Documents found for question `67fa3c5818b1e36f2e000109`: 50
# Documents found for question `6810c54b353a4a2e6b000011`: 50
# Documents found for question `67fd5d6518b1e36f2e000138`: 50
# Documents found for question `67fb046e18b1e36f2e00010c`: 2
# Documents found for question `67d6bbfa18b1e36f2e000020`: 50
# Documents found for question `680fe1e3353a4a2e6b00000f`: 50
# Documents found for question `680d5dd8353a4a2e6b000004`: 32
# Documents found for question `67d7208218b1e36f2e00002e`: 50
# Documents found for question `67fc381f18b1e36f2e00012f`: 50
# Documents found for question `67c9e46881b1027333000004`: 50
# Documents found for question `67fbe2ab18b1e36f2e000116`: 49
# Documents found for question `67eaf14c18b1e36f2e0000de`: 31
# Documents found for question `67c9e7ee81b1027333000007`: 32
# Documents found for question `67d71d8f18b1e36f2e00002b`: 50
# Documents found for question `67cdb26a81b1027333000017`: 0
# Documents found for question `67e2b0a018b1e36f2e00008b`: 50
# Documents found for question `67e090be18b1e36f2e00006c`: 50
# Documents found for question `67d7fded18b1e36f2e000042`: 50

# %% [markdown]
# ### Step 3: Rank documents with "Traditional IR" model

# %%
from rank_bm25 import BM25Okapi

def apply_bm25_ranking(bioasq_13b_questions):
    """
    Apply BM25 ranking to the documents of each question in the BioASQ 13b dataset.
    """
    # For each question, concatenate the title and abstract of each of its document
    for question in bioasq_13b_questions:
        full_doc = [doc["title"] + " " + doc["documentAbstract"] for doc in question['documents_api']]
        # Tokenize the full documents (title + abstract) of the question
        tokenized_docs = [word_tokenize(doc.lower()) for doc in full_doc if doc.strip()]

        # Ensure there are no empty tokenized documents
        if not tokenized_docs:
            print(f"No documents to rank for question `{question['id']}`.")
            continue

        # Tokenize the question (question body)
        tokenized_question = word_tokenize(question['body'].lower())

        # Create bm25 instance
        bm25 = BM25Okapi(tokenized_docs)

        # Get the scores for the query
        scores = bm25.get_scores(tokenized_question)

        # Sort documents by score
        ranked_docs = sorted(zip(question['documents_api'], scores), key=lambda x: x[1], reverse=True)

        print(f"Ranked documents for question `{question['id']}`:")
        
        # Append the top 10 documents to each question
        for doc, score in ranked_docs[:10]:
            question['documents'].append(f"http://www.ncbi.nlm.nih.gov/pubmed/{doc['pmid']}")
            print(f"Document ID: {doc['pmid']}, Score: {score}")
        print("\n")

     
    return [
        {
            'id': question['id'],
            'type': question['type'],
            'body': question['body'],
            'documents': question['documents']
        }
        for question in bioasq_13b_questions
    ]

# %% [markdown]
# #### Hybrid model: rerank using cosine similarity

# %%
import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
# Load model
tokenizer = AutoTokenizer.from_pretrained("dmis-lab/biobert-base-cased-v1.1")
model = AutoModel.from_pretrained("dmis-lab/biobert-base-cased-v1.1")
model.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(28996, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output.last_hidden_state  # (batch_size, seq_len, hidden_size)
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

def embed_text(texts):
    encoded_input = tokenizer(texts, padding=True, truncation=True, return_tensors='pt', max_length=512)
    encoded_input = {k: v.to(device) for k, v in encoded_input.items()}

    with torch.no_grad():
        model_output = model(**encoded_input)
    embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
    return embeddings.cpu().numpy()

def rerank_with_embeddings(question, docs):
    question_embedding = embed_text(question)
    if question_embedding.ndim == 1:
        question_embedding = question_embedding.reshape(1, -1)

    doc_embeddings = [embed_text(doc).squeeze() for doc in docs]
    doc_embeddings = np.array(doc_embeddings)

    # print("Question embedding shape:", question_embedding.shape)
    # print("Doc_embeddings shape:", doc_embeddings.shape)
    # print("Documents shape:", [emb.shape for emb in doc_embeddings])
    # Question embedding shape: (1, hidden_size)
    # Transform documents embeddings to a 2D array
    
    similarities = cosine_similarity(question_embedding, doc_embeddings)[0] # type: ignore
    return sorted(zip(docs, similarities), key=lambda x: x[1], reverse=True)

# %%
from rank_bm25 import BM25Okapi
from nltk.tokenize import word_tokenize
#from utils_neural import rerank_with_embeddings

def apply_bm25_with_reranking(bioasq_13b_questions):
    """
    Apply BM25 followed by BioBERT-based reranking to the documents of each question.
    """
    for question in bioasq_13b_questions:
        question['documents'] = []  # Ensure the 'documents' list is initialized
        full_docs = [doc["title"] + " " + doc["documentAbstract"] for doc in question['documents_api']]
        tokenized_docs = [word_tokenize(doc.lower()) for doc in full_docs if doc.strip()]

        if not tokenized_docs:
            print(f"No documents to rank for question `{question['id']}`.")
            continue

        tokenized_question = word_tokenize(question['body'].lower())
        bm25 = BM25Okapi(tokenized_docs)
        scores = bm25.get_scores(tokenized_question)

        # Step 1: BM25 retrieval (top 50)
        ranked_docs = sorted(zip(question['documents_api'], scores), key=lambda x: x[1], reverse=True)
        top_candidates = ranked_docs[:50]

        candidate_texts = [doc["title"] + " " + doc["documentAbstract"] for doc, _ in top_candidates]

        # Step 2: Neural reranking using BioBERT
        try:
            reranked = rerank_with_embeddings(question['body'], candidate_texts)
        except Exception as e:
            print(f"Embedding error for question `{question['id']}`: {e}")
            continue

        # Step 3: Select top 10 reranked docs and map back to PMIDs
        top_reranked_docs = reranked[:10]
        seen_pmids = set()
        for reranked_text, _ in top_reranked_docs:
            for doc, _ in top_candidates:
                full_text = doc["title"] + " " + doc["documentAbstract"]
                if full_text == reranked_text and doc["pmid"] not in seen_pmids:
                    question['documents'].append(f"http://www.ncbi.nlm.nih.gov/pubmed/{doc['pmid']}")
                    seen_pmids.add(doc["pmid"])
                    break

        print(f"Reranked top documents for question `{question['id']}`:")
        for url in question['documents']:
            print(url)
        print("\n")

    return [
        {
            'id': question['id'],
            'type': question['type'],
            'body': question['body'],
            'documents': question['documents']
        }
        for question in bioasq_13b_questions
    ]

# %%
from rank_bm25 import BM25Okapi

def apply_bm25_ranking_dynamic(bioasq_13b_questions, k1=1.5, b=0.6, min_score_ratio=0.5):
    """
    Apply BM25 ranking with dynamic cutoff based on score drop-off and tunable parameters.
    - k1, b: BM25 parameters
    - min_score_ratio: minimum relative score threshold (e.g. 0.5 means keep docs with ≥ 50% of top score)
    """
    for question in bioasq_13b_questions:
        full_doc = [doc["title"] + " " + doc["documentAbstract"] for doc in question['documents_api']]
        tokenized_docs = [word_tokenize(doc.lower()) for doc in full_doc if doc.strip()]

        if not tokenized_docs:
            print(f"No documents to rank for question `{question['id']}`.")
            continue

        tokenized_question = word_tokenize(question['body'].lower())
        bm25 = BM25Okapi(tokenized_docs, k1=k1, b=b)
        scores = bm25.get_scores(tokenized_question)

        ranked_docs = sorted(zip(question['documents_api'], scores), key=lambda x: x[1], reverse=True)

        # top_score = ranked_docs[0][1] if ranked_docs else 0
        # score_threshold = top_score * min_score_ratio

        # # Filter dynamically: keep docs above relative score threshold, max 10
        # filtered_docs = [(doc, score) for doc, score in ranked_docs if score >= score_threshold][:10]

        question['documents'] = []  # ensure it's fresh
        for doc, score in ranked_docs[:7]:
            question['documents'].append(f"http://www.ncbi.nlm.nih.gov/pubmed/{doc['pmid']}")
            print(f"Doc ID: {doc['pmid']}, Score: {score:.3f}")

        # print(f"Selected {len(ranked_docs)} documents for question `{question['id']}`.\n")

    return [
        {
            'id': question['id'],
            'type': question['type'],
            'body': question['body'],
            'documents': question['documents']
        }
        for question in bioasq_13b_questions
    ]

# %%
# traditional_ranked_questions = apply_bm25_ranking(bioasq_13b_questions)
traditional_ranked_questions = apply_bm25_with_reranking(bioasq_13b_questions)
# Out:
# No documents to rank for question `67e6cf2618b1e36f2e0000d0`.
# Reranked top documents for question `680d5e47353a4a2e6b000005`:
# http://www.ncbi.nlm.nih.gov/pubmed/40401042
# http://www.ncbi.nlm.nih.gov/pubmed/40376811
# http://www.ncbi.nlm.nih.gov/pubmed/40425105
# http://www.ncbi.nlm.nih.gov/pubmed/40364221
# http://www.ncbi.nlm.nih.gov/pubmed/40399434
# http://www.ncbi.nlm.nih.gov/pubmed/40422578
# http://www.ncbi.nlm.nih.gov/pubmed/40439531
# http://www.ncbi.nlm.nih.gov/pubmed/40434689
# http://www.ncbi.nlm.nih.gov/pubmed/40428781
# http://www.ncbi.nlm.nih.gov/pubmed/40370483
#
#
# Reranked top documents for question `680f4a68353a4a2e6b000007`:
# http://www.ncbi.nlm.nih.gov/pubmed/40351432
# http://www.ncbi.nlm.nih.gov/pubmed/40362522
# http://www.ncbi.nlm.nih.gov/pubmed/40431505
# http://www.ncbi.nlm.nih.gov/pubmed/40356716
# http://www.ncbi.nlm.nih.gov/pubmed/40384036
# http://www.ncbi.nlm.nih.gov/pubmed/40068939
#
#
# No documents to rank for question `67cdb26a81b1027333000017`.
# Reranked top documents for question `67e2b0a018b1e36f2e00008b`:
# http://www.ncbi.nlm.nih.gov/pubmed/40183686
# http://www.ncbi.nlm.nih.gov/pubmed/40276335
# http://www.ncbi.nlm.nih.gov/pubmed/40308964
# http://www.ncbi.nlm.nih.gov/pubmed/40405904
# http://www.ncbi.nlm.nih.gov/pubmed/40201815
# http://www.ncbi.nlm.nih.gov/pubmed/40235931
# http://www.ncbi.nlm.nih.gov/pubmed/40142518
# http://www.ncbi.nlm.nih.gov/pubmed/40222947
# http://www.ncbi.nlm.nih.gov/pubmed/40268194
# http://www.ncbi.nlm.nih.gov/pubmed/40372095
#
#
# Reranked top documents for question `67e090be18b1e36f2e00006c`:
# http://www.ncbi.nlm.nih.gov/pubmed/39773923
# http://www.ncbi.nlm.nih.gov/pubmed/40381158
# http://www.ncbi.nlm.nih.gov/pubmed/40276429
# http://www.ncbi.nlm.nih.gov/pubmed/40167960
# http://www.ncbi.nlm.nih.gov/pubmed/38879179
# http://www.ncbi.nlm.nih.gov/pubmed/38467323
# http://www.ncbi.nlm.nih.gov/pubmed/39952008
# http://www.ncbi.nlm.nih.gov/pubmed/40333040
# http://www.ncbi.nlm.nih.gov/pubmed/39393642
# http://www.ncbi.nlm.nih.gov/pubmed/39335028
#
#
# Reranked top documents for question `67d7fded18b1e36f2e000042`:
# http://www.ncbi.nlm.nih.gov/pubmed/39141159
# http://www.ncbi.nlm.nih.gov/pubmed/40284941
# http://www.ncbi.nlm.nih.gov/pubmed/39759166
# http://www.ncbi.nlm.nih.gov/pubmed/38701969
# http://www.ncbi.nlm.nih.gov/pubmed/38706519
# http://www.ncbi.nlm.nih.gov/pubmed/39182131
# http://www.ncbi.nlm.nih.gov/pubmed/40442335
# http://www.ncbi.nlm.nih.gov/pubmed/40075274
# http://www.ncbi.nlm.nih.gov/pubmed/38770770
# http://www.ncbi.nlm.nih.gov/pubmed/39684856

# %% [markdown]
# ## Evaluate the model vs gold standard

# %%
from metrics import (
    format_for_metric_evaluation,
    evaluate_model
)

# Format the results for evaluation
retrieved_docs = format_for_metric_evaluation(traditional_ranked_questions, "documents")
gold_docs = format_for_metric_evaluation(bioasq_13b_questions, "target_documents")

# Calculate the evaluation metrics
map_score = evaluate_model(retrieved_docs, gold_docs, "map")
mean_precision_score = evaluate_model(retrieved_docs, gold_docs, "mean_precision")
recall_score = evaluate_model(retrieved_docs, gold_docs, "mean_recall")
f1_score = evaluate_model(retrieved_docs, gold_docs, "f1_score")

# Print the results
print("MAP:", map_score)
print("Mean Precision:", mean_precision_score)
print("Recall:", recall_score)
print("F1 Score:", f1_score)
# Out:
# MAP: 0.019637721755368813
# Mean Precision: 0.024705882352941178
# Recall: 0.05529411764705883
# F1 Score: 0.02754412254412254

# %% [markdown]
# ## Save the results

# %%
from utils import save_results_to_json

save_results_to_json(traditional_ranked_questions, filename = '../output/results_traditional_model_hybrid.json')
# Out:
# 'Results saved to ../output/results_traditional_model_hybrid.json'

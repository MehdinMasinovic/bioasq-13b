# %%
# Importing necessary libraries
import requests
import json
import string

import nltk
from nltk.tokenize import word_tokenize

# %%
import ssl

# Diable SSL verification to avoid certificate errors when downloaing nltk resources
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

# Download nltk stopwords and punkt tokenizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/khasrurrahman/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/khasrurrahman/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/khasrurrahman/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# ## Loading training data

# %%
from utils import load_bioasq_questions
bioasq_13b_questions = load_bioasq_questions('../data/BioASQ-training13b/training13b.json', num_questions=3, test=True)

# Check the number of questions
print(f"Number of BioASQ 13b questions: {len(bioasq_13b_questions)}")
# Out:
# Number of BioASQ 13b questions: 3

# %% [markdown]
# ## PubMed's API

# %% [markdown]
# ## Traditional IR model

# %% [markdown]
# ### Step 1: Extract keywords from questions

# %% [markdown]
# #### Ideal preprocessing - Apply word2vec

# %%
from utils import load_vectors_gensim

types_file = '../data/word2vecTools/types.txt'
vectors_file = '../data/word2vecTools/vectors.txt'

w2v_model = load_vectors_gensim(types_file, vectors_file, 200)

# %%
from utils import expand_question_with_w2v, build_boolean_query

def expand_question(question):

    question['keywords'] = expand_question_with_w2v(question['body'], w2v_model)

    question['query'] = build_boolean_query(question['keywords'])

    return question

for i, question in enumerate(bioasq_13b_questions):
    # Expand the question using word2vec
    question = expand_question(question)

    # Print the expanded question
    print(f"Expanded Question {i+1}:")
    print(f"Keywords: {question['keywords']}")
    print(f"Query: {question['query']}")
    print()
# Out:
# Expanded Question 1:
# Keywords: {'hirschsprung': ['hirschsprungs', 'hscr', 'hirschprungs'], 'disease': ['proctor-dix', 'balneoreactions', 'vkorc-1'], 'mendelian': ['non-mendelian', 'codominant', 'inheritance'], 'multifactorial': ['multi-factorial', 'polygenic', 'multifactoral'], 'disorder': ['disorders', 'hypocondriasis', 'mdd']}
# Query: (hirschsprung OR hirschsprungs OR hscr OR hirschprungs) AND (disease OR proctor-dix OR balneoreactions OR vkorc-1) AND (mendelian OR non-mendelian OR codominant OR inheritance) AND (multifactorial OR multi-factorial OR polygenic OR multifactoral) AND (disorder OR disorders OR hypocondriasis OR mdd)
#
# Expanded Question 2:
# Keywords: {'list': ['lists', 'listing', 'to-do'], 'signaling': ['signalling', 'signal-transduction', 'raserk'], 'molecules': ['molecule', 'icams', 'ligands'], 'ligands': ['ligand', 'receptors', '3hopioid'], 'interact': ['associate', 'bind', 'interacts'], 'receptor': ['receptors', 'hmc5', '5-nonyloxytryptamine'], 'egfr': ['erbb2', 'egfrs', 'erbb-2']}
# Query: (list OR lists OR listing OR to-do) AND (signaling OR signalling OR signal-transduction OR raserk) AND (molecules OR molecule OR icams OR ligands) AND (ligands OR ligand OR receptors OR 3hopioid) AND (interact OR associate OR bind OR interacts) AND (receptor OR receptors OR hmc5 OR 5-nonyloxytryptamine) AND (egfr OR erbb2 OR egfrs OR erbb-2)
#
# Expanded Question 3:
# Keywords: {'protein': ['proteins', 'a-anchoring', 'pka-anchoring'], 'papilin': ['lim-containing', 'adt-1', 'twinstar'], 'secreted': ['secrete', 'membrane-anchored', 'secretes']}
# Query: (protein OR proteins OR a-anchoring OR pka-anchoring) AND (papilin OR lim-containing OR adt-1 OR twinstar) AND (secreted OR secrete OR membrane-anchored OR secretes)

# %% [markdown]
# ### Step 2: Consume PubMed's API to get relevant documents

# %%
# Get the most relevant documents for each question according to the PubMed API
# and save them in a new attribute documents_api
from utils import get_most_relevant_documents

for question in bioasq_13b_questions:
    documents = get_most_relevant_documents(question['query'], page=0, documents_per_page=50)
    question['documents_api'] = documents
    question['documents'] = []

    print(f"Documents found for question `{question['id']}`: {len(documents)}")
# Out:
# Documents found for question `55031181e9bde69634000014`: 32
# Documents found for question `55046d5ff8aee20f27000007`: 26
# Documents found for question `54e25eaaae9738404b000017`: 50

# %% [markdown]
# ### Step 3: Rank documents with "Traditional IR" model

# %%
from rank_bm25 import BM25Okapi

def apply_bm25_ranking(bioasq_13b_questions):
    """
    Apply BM25 ranking to the documents of each question in the BioASQ 13b dataset.
    """
    # For each question, concatenate the title and abstract of each of its document
    for question in bioasq_13b_questions:
        full_doc = [doc["title"] + " " + doc["documentAbstract"] for doc in question['documents_api']]
        # Tokenize the full documents (title + abstract) of the question
        tokenized_docs = [word_tokenize(doc.lower()) for doc in full_doc if doc.strip()]

        # Ensure there are no empty tokenized documents
        if not tokenized_docs:
            print(f"No documents to rank for question `{question['id']}`.")
            continue

        # Tokenize the question (question body)
        tokenized_question = word_tokenize(question['body'].lower())

        # Create bm25 instance
        bm25 = BM25Okapi(tokenized_docs)

        # Get the scores for the query
        scores = bm25.get_scores(tokenized_question)

        # Sort documents by score
        ranked_docs = sorted(zip(question['documents_api'], scores), key=lambda x: x[1], reverse=True)

        print(f"Ranked documents for question `{question['id']}`:")
        
        # Append the top 10 documents to each question
        for doc, score in ranked_docs[:10]:
            question['documents'].append(f"http://www.ncbi.nlm.nih.gov/pubmed/{doc['pmid']}")
            print(f"Document ID: {doc['pmid']}, Score: {score}")
        print("\n")

     
    return [
        {
            'id': question['id'],
            'type': question['type'],
            'body': question['body'],
            'documents': question['documents']
        }
        for question in bioasq_13b_questions
    ]


traditional_ranked_questions = apply_bm25_ranking(bioasq_13b_questions)
# Out:
# Ranked documents for question `55031181e9bde69634000014`:
# Document ID: 11106284, Score: 9.32838914388656
# Document ID: 20027720, Score: 8.703849221024097
# Document ID: 23001136, Score: 8.30897991726375
# Document ID: 6823428, Score: 7.839336025034514
# Document ID: 11694544, Score: 7.8146101971081885
# Document ID: 15858239, Score: 7.7696821666555556
# Document ID: 9359036, Score: 7.678000863673339
# Document ID: 15617541, Score: 7.621918091041559
# Document ID: 34422713, Score: 7.393250680138278
# Document ID: 2309705, Score: 7.353302315603599
#
#
# Ranked documents for question `55046d5ff8aee20f27000007`:
# Document ID: 7908191, Score: 11.078693123564259
# Document ID: 27790245, Score: 9.665749023859654
# Document ID: 35113412, Score: 9.283902434254362
# Document ID: 25863072, Score: 9.233415317533753
# Document ID: 19429859, Score: 9.21976969746465
# Document ID: 30268436, Score: 8.661351606942816
# Document ID: 16140938, Score: 8.166223642045665
# Document ID: 32227891, Score: 8.158444199125377
# Document ID: 24127898, Score: 7.495752222080486
# Document ID: 14708119, Score: 7.352612236081012
#
#
# Ranked documents for question `54e25eaaae9738404b000017`:
# Document ID: 15094122, Score: 7.547065193033994
# Document ID: 38284126, Score: 6.62500942758523
# Document ID: 16571634, Score: 5.784203078346655
# Document ID: 21784067, Score: 5.284398711188434
# Document ID: 38837578, Score: 4.229552886129661
# Document ID: 39169693, Score: 3.906778532776297
# Document ID: 40094323, Score: 3.874819091925814
# Document ID: 19297413, Score: 3.7448901689661582
# Document ID: 20805556, Score: 3.572977624991897
# Document ID: 29678203, Score: 3.5297096971663136

# %% [markdown]
# ## Evaluate the model vs gold standard

# %%
from metrics import (
    format_for_metric_evaluation,
    evaluate_model
)

# Format the results for evaluation
retrieved_docs = format_for_metric_evaluation(traditional_ranked_questions, "documents")
gold_docs = format_for_metric_evaluation(bioasq_13b_questions, "target_documents")

# Calculate the evaluation metrics
map_score = evaluate_model(retrieved_docs, gold_docs, "map")
mean_precision_score = evaluate_model(retrieved_docs, gold_docs, "mean_precision")
recall_score = evaluate_model(retrieved_docs, gold_docs, "mean_recall")
f1_score = evaluate_model(retrieved_docs, gold_docs, "f1_score")

# Print the results
print("MAP:", map_score)
print("Mean Precision:", mean_precision_score)
print("Recall:", recall_score)
print("F1 Score:", f1_score)
# Out:
# MAP: 0.20764610633031685
# Mean Precision: 0.2333333333333333
# Recall: 0.48888888888888893
# F1 Score: 0.31570881226053643

# %% [markdown]
# ## Save the results

# %%
from utils import save_results_to_json

save_results_to_json(traditional_ranked_questions, filename = '../output/results_traditional_model.json')
# Out:
# 'Results saved to ../output/results_traditional_model.json'
